# %% [markdown]
# # Count frequency of each element in the array

# %%
A = [1,2,3,3,2,2,1,1]

d = {}

for i in A:
    if i in d:
        d[i] += 1
    else:
        d[i] = 1

print(d)
# Out:
# {1: 3, 2: 3, 3: 2}
