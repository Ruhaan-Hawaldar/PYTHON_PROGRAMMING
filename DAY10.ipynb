# %% [markdown]
# # Reverse a given Array

# %%
N = [1,2,3,4,5]
A = []
for i in range(len(N)-1,-1,-1):
    A.append(N[i])

print(A)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## using library

# %%
N = [1,2,3,4,5]
N.reverse()
print(N)
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## using indexing

# %%
N = [1,2,3,4,5]

A = N[::-1]

print(A)
# Out:
# [5, 4, 3, 2, 1]
