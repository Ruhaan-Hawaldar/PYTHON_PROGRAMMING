# %% [markdown]
# # ANAGRAM
#
# 2 words having same letters

# %%
word1 = input("Enter string1:")
word2 = input("Enter string2:")

word1 = word1.replace(" ","")


word2 = word2.replace(" ","")


if sorted(word1.lower()) == sorted(word2.lower()):
    print("anagram")
else:
    print("Not anagram")
# Out:
# Enter string1: python
# Enter string2: Typhpon
# Not anagram
