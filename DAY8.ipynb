# %% [markdown]
# # SUM OF N NUMBERS

# %%
N = int(input("Enter Number:"))
sum_1 = 0

for i in range(1,N+1):
    sum_1 = sum_1 + i

print(sum_1)
# Out:
# Enter Number: 5
# 15

# %%
# using formula 

A = int(input("Enter Number:"))

sum_2 = (A*(A+1)) / 2

print(sum_2)
# Out:
# Enter Number: 5
# 15.0
